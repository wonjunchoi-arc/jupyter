# %%
import pandas as pd
import pandas as pd
import numpy as np
import random
import string
np.random.seed(56)

# %%
def id():
    return ''.join(random.choice(string.ascii_letters) for i in range(5))

# %%
def score():
    return np.random.randint(0,100)

# %%
df=pd.DataFrame({"국어":[score()for i in range(10)],"영어":[score()for i in range(10)],"수학":[score()for i in range(10)],"사회":[score()for i in range(10)],}, index=[id() for i in range(10)])

# %%
df.loc[['JDnJh''feXxM']]
# Out:
#   File "<ipython-input-35-fbd51146eddf>", line 1
#     df.loc[['JDnJh':'feXxM']]
#                    ^
# SyntaxError: invalid syntax

# %%
df.iloc[[0],:]
# Out:
#        국어  영어  수학  사회
# JDnJh  78  94  56   8

# %%
df
# Out:
# [13, 23, 22, 48, 83, 52, 39, 50, 20, 5]

# %%
df=pd.DataFrame({"국어":[score()for i in range(10)],"영어":[score()for i in range(10)],"수학":[score()for i in range(10)],"사회":[score()for i in range(10)],}, index=[id() for i in range(10)])

# %%
df
# Out:
#        국어  영어  수학  사회
# OBDZS  72  31  78  84
# sCoTy  15  65  20  62
# UBQHd  37  19  51  72
# pLiwC  51  47  73  25
# POUaQ  24  83  39  96
# gHYyR  32  66  86   1
# bDrAx  90  69  23  75
# ctVyA  26  69  87  65
# RXwiF  91  97  46  67
# feXxM  79  27  48  22

# %%
df.loc[:,'과학']=pd.Series([score() for i in range(10)], index = df.index)

# %%
df
# Out:
#        국어  영어  수학  사회  과학
# OBDZS  72  31  78  84  32
# sCoTy  15  65  20  62  63
# UBQHd  37  19  51  72  29
# pLiwC  51  47  73  25  67
# POUaQ  24  83  39  96  53
# gHYyR  32  66  86   1  60
# bDrAx  90  69  23  75  70
# ctVyA  26  69  87  65  14
# RXwiF  91  97  46  67  66
# feXxM  79  27  48  22  36

# %%
#각 학생들의 점수의 총합을 표현하는 컬럼을 추가하세요
# Out:
# OBDZS    297
# sCoTy    225
# UBQHd    208
# pLiwC    263
# POUaQ    295
# gHYyR    245
# bDrAx    327
# ctVyA    261
# RXwiF    367
# feXxM    212
# Name: 총합, dtype: int64

# %%
df["과학":[score() for i in range(10)]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '과학'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-5cc1049a618d> in <module>
# ...

# %%
df.loc[:,'총합']=df.sum(axis=1)
df
# Out:
#        국어  영어  수학  사회  과학   총합
# OBDZS  72  31  78  84  32  297
# sCoTy  15  65  20  62  63  225
# UBQHd  37  19  51  72  29  208
# pLiwC  51  47  73  25  67  263
# POUaQ  24  83  39  96  53  295
# gHYyR  32  66  86   1  60  245
# bDrAx  90  69  23  75  70  327
# ctVyA  26  69  87  65  14  261
# RXwiF  91  97  46  67  66  367
# feXxM  79  27  48  22  36  212

# %%
df = df.loc[:,df.columns !="총합"]
df
# Out:
#        국어  영어  수학  사회  과학          평균
# OBDZS  72  31  78  84  32   99.000000
# sCoTy  15  65  20  62  63   75.000000
# UBQHd  37  19  51  72  29   69.333333
# pLiwC  51  47  73  25  67   87.666667
# POUaQ  24  83  39  96  53   98.333333
# gHYyR  32  66  86   1  60   81.666667
# bDrAx  90  69  23  75  70  109.000000
# ctVyA  26  69  87  65  14   87.000000
# RXwiF  91  97  46  67  66  122.333333
# feXxM  79  27  48  22  36   70.666667

# %%
df.loc[:,'평균']=df.mean(axis=1)
df
# Out:
#        국어  영어  수학  사회  과학         평균
# OBDZS  72  31  78  84  32  66.000000
# sCoTy  15  65  20  62  63  50.000000
# UBQHd  37  19  51  72  29  46.222222
# pLiwC  51  47  73  25  67  58.444444
# POUaQ  24  83  39  96  53  65.555556
# gHYyR  32  66  86   1  60  54.444444
# bDrAx  90  69  23  75  70  72.666667
# ctVyA  26  69  87  65  14  58.000000
# RXwiF  91  97  46  67  66  81.555556
# feXxM  79  27  48  22  36  47.111111

# %%
df.loc[len(df)]=["아랍어",[score() for i in range(10)]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-dda01a3b1496> in <module>
# ----> 1 df.loc[len(df)]=["아랍어",[score() for i in range(10)]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1627
#    1628             if missing:
# -> 1629                 self._setitem_with_indexer_missing(indexer, value)
#    1630                 return
#    1631
#
# ...

# %%
df
# Out:
#        국어  영어  수학  사회  과학         평균
# OBDZS  72  31  78  84  32  66.000000
# sCoTy  15  65  20  62  63  50.000000
# UBQHd  37  19  51  72  29  46.222222
# pLiwC  51  47  73  25  67  58.444444
# POUaQ  24  83  39  96  53  65.555556
# gHYyR  32  66  86   1  60  54.444444
# bDrAx  90  69  23  75  70  72.666667
# ctVyA  26  69  87  65  14  58.000000
# RXwiF  91  97  46  67  66  81.555556
# feXxM  79  27  48  22  36  47.111111

# %%
df=df.drop('평균', axis=1)

# %%
df
# Out:
#        국어  영어  수학  사회  과학
# OBDZS  72  31  78  84  32
# sCoTy  15  65  20  62  63
# UBQHd  37  19  51  72  29
# pLiwC  51  47  73  25  67
# POUaQ  24  83  39  96  53
# gHYyR  32  66  86   1  60
# bDrAx  90  69  23  75  70
# ctVyA  26  69  87  65  14
# RXwiF  91  97  46  67  66
# feXxM  79  27  48  22  36

# %%
df.loc['총합']=df.sum(axis=1)

# %%
df
# Out:
#          국어    영어    수학    사회    과학
# OBDZS  72.0  31.0  78.0  84.0  32.0
# sCoTy  15.0  65.0  20.0  62.0  63.0
# UBQHd  37.0  19.0  51.0  72.0  29.0
# pLiwC  51.0  47.0  73.0  25.0  67.0
# POUaQ  24.0  83.0  39.0  96.0  53.0
# gHYyR  32.0  66.0  86.0   1.0  60.0
# bDrAx  90.0  69.0  23.0  75.0  70.0
# ctVyA  26.0  69.0  87.0  65.0  14.0
# RXwiF  91.0  97.0  46.0  67.0  66.0
# feXxM  79.0  27.0  48.0  22.0  36.0
# 총합      NaN   NaN   NaN   NaN   NaN

# %%
df.drop('총합')
# Out:
#          국어    영어    수학    사회    과학
# OBDZS  72.0  31.0  78.0  84.0  32.0
# sCoTy  15.0  65.0  20.0  62.0  63.0
# UBQHd  37.0  19.0  51.0  72.0  29.0
# pLiwC  51.0  47.0  73.0  25.0  67.0
# POUaQ  24.0  83.0  39.0  96.0  53.0
# gHYyR  32.0  66.0  86.0   1.0  60.0
# bDrAx  90.0  69.0  23.0  75.0  70.0
# ctVyA  26.0  69.0  87.0  65.0  14.0
# RXwiF  91.0  97.0  46.0  67.0  66.0
# feXxM  79.0  27.0  48.0  22.0  36.0

# %%
df['총합']=df.sum(axis=1)
df
# Out:
#          국어    영어    수학    사회    과학     총합
# OBDZS  72.0  31.0  78.0  84.0  32.0  297.0
# sCoTy  15.0  65.0  20.0  62.0  63.0  225.0
# UBQHd  37.0  19.0  51.0  72.0  29.0  208.0
# pLiwC  51.0  47.0  73.0  25.0  67.0  263.0
# POUaQ  24.0  83.0  39.0  96.0  53.0  295.0
# gHYyR  32.0  66.0  86.0   1.0  60.0  245.0
# bDrAx  90.0  69.0  23.0  75.0  70.0  327.0
# ctVyA  26.0  69.0  87.0  65.0  14.0  261.0
# RXwiF  91.0  97.0  46.0  67.0  66.0  367.0
# feXxM  79.0  27.0  48.0  22.0  36.0  212.0
# 총합      NaN   NaN   NaN   NaN   NaN    0.0

# %%
df=df.drop('총합')

# %%
df
# Out:
#          국어    영어    수학    사회    과학     총합
# OBDZS  72.0  31.0  78.0  84.0  32.0  297.0
# sCoTy  15.0  65.0  20.0  62.0  63.0  225.0
# UBQHd  37.0  19.0  51.0  72.0  29.0  208.0
# pLiwC  51.0  47.0  73.0  25.0  67.0  263.0
# POUaQ  24.0  83.0  39.0  96.0  53.0  295.0
# gHYyR  32.0  66.0  86.0   1.0  60.0  245.0
# bDrAx  90.0  69.0  23.0  75.0  70.0  327.0
# ctVyA  26.0  69.0  87.0  65.0  14.0  261.0
# RXwiF  91.0  97.0  46.0  67.0  66.0  367.0
# feXxM  79.0  27.0  48.0  22.0  36.0  212.0

# %%
df=df['과목총합']=df.sum()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dde89be1d30f> in <module>
# ----> 1 df=df['과목총합']=df.sum()
#       2 df
#
# NameError: name 'df' is not defined

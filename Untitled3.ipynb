# %%
import pandas as pd
import pandas as pd
import numpy as np
import random
import string
np.random.seed(56)

# %%
def id():
    return ''.join(random.choice(string.ascii_letters) for i in range(5))

# %%
def score():
    return np.random.randint(0,100)

# %%
df=pd.DataFrame({"국어":[score()for i in range(10)],"영어":[score()for i in range(10)],"수학":[score()for i in range(10)],"사회":[score()for i in range(10)],}, index=[id() for i in range(10)])

# %%
df
# Out:
#        국어  영어  수학  사회
# sXRfu  85  24  28  74
# iEqdF  15  12  37  65
# lpFzN  64  66  34  16
# gYgFi  34  43  15  13
# uIhMh  14  11  28  20
# CZAOd  87  80  89  44
# fjNKW  22  33  19  32
# sPGVd  57  89  69   8
# XGVUv  90  10  41  29
# DHxIc  55  31  66  94

# %%
df['총점']=df.sum()

# %%
df
# Out:
#        국어  영어  수학  사회  총점
# sXRfu  85  24  28  74 NaN
# iEqdF  15  12  37  65 NaN
# lpFzN  64  66  34  16 NaN
# gYgFi  34  43  15  13 NaN
# uIhMh  14  11  28  20 NaN
# CZAOd  87  80  89  44 NaN
# fjNKW  22  33  19  32 NaN
# sPGVd  57  89  69   8 NaN
# XGVUv  90  10  41  29 NaN
# DHxIc  55  31  66  94 NaN

# %%
df=df.drop('총점',axis=1)

# %%
df
# Out:
#        국어  영어  수학  사회
# sXRfu  85  24  28  74
# iEqdF  15  12  37  65
# lpFzN  64  66  34  16
# gYgFi  34  43  15  13
# uIhMh  14  11  28  20
# CZAOd  87  80  89  44
# fjNKW  22  33  19  32
# sPGVd  57  89  69   8
# XGVUv  90  10  41  29
# DHxIc  55  31  66  94

# %%
df['총점']=df.sum(axis=1)

# %%
df
# Out:
#        국어  영어  수학  사회   총점
# sXRfu  85  24  28  74  211
# iEqdF  15  12  37  65  129
# lpFzN  64  66  34  16  180
# gYgFi  34  43  15  13  105
# uIhMh  14  11  28  20   73
# CZAOd  87  80  89  44  300
# fjNKW  22  33  19  32  106
# sPGVd  57  89  69   8  223
# XGVUv  90  10  41  29  170
# DHxIc  55  31  66  94  246

# %%
df['과목총점']=df.sum()

# %%
df
# Out:
#        국어  영어  수학  사회   총점  과목총점
# sXRfu  85  24  28  74  211   NaN
# iEqdF  15  12  37  65  129   NaN
# lpFzN  64  66  34  16  180   NaN
# gYgFi  34  43  15  13  105   NaN
# uIhMh  14  11  28  20   73   NaN
# CZAOd  87  80  89  44  300   NaN
# fjNKW  22  33  19  32  106   NaN
# sPGVd  57  89  69   8  223   NaN
# XGVUv  90  10  41  29  170   NaN
# DHxIc  55  31  66  94  246   NaN

# %%
df=df.drop('과목총점', axis=1)

# %%
df
# Out:
#        국어  영어  수학  사회   총점
# sXRfu  85  24  28  74  211
# iEqdF  15  12  37  65  129
# lpFzN  64  66  34  16  180
# gYgFi  34  43  15  13  105
# uIhMh  14  11  28  20   73
# CZAOd  87  80  89  44  300
# fjNKW  22  33  19  32  106
# sPGVd  57  89  69   8  223
# XGVUv  90  10  41  29  170
# DHxIc  55  31  66  94  246

# %%
df.loc['과목총점']=df.sum()

# %%
df
# Out:
#         국어   영어   수학   사회    총점
# sXRfu   85   24   28   74   211
# iEqdF   15   12   37   65   129
# lpFzN   64   66   34   16   180
# gYgFi   34   43   15   13   105
# uIhMh   14   11   28   20    73
# CZAOd   87   80   89   44   300
# fjNKW   22   33   19   32   106
# sPGVd   57   89   69    8   223
# XGVUv   90   10   41   29   170
# DHxIc   55   31   66   94   246
# 과목총점   523  399  426  395  1743

# %%
df.sort_values('국어', ascending=False)
# Out:
#         국어   영어   수학   사회    총점
# 과목총점   523  399  426  395  1743
# XGVUv   90   10   41   29   170
# CZAOd   87   80   89   44   300
# sXRfu   85   24   28   74   211
# lpFzN   64   66   34   16   180
# sPGVd   57   89   69    8   223
# DHxIc   55   31   66   94   246
# gYgFi   34   43   15   13   105
# fjNKW   22   33   19   32   106
# iEqdF   15   12   37   65   129
# uIhMh   14   11   28   20    73

# %%
df
# Out:
#         국어   영어   수학   사회    총점
# sXRfu   85   24   28   74   211
# iEqdF   15   12   37   65   129
# lpFzN   64   66   34   16   180
# gYgFi   34   43   15   13   105
# uIhMh   14   11   28   20    73
# CZAOd   87   80   89   44   300
# fjNKW   22   33   19   32   106
# sPGVd   57   89   69    8   223
# XGVUv   90   10   41   29   170
# DHxIc   55   31   66   94   246
# 과목총점   523  399  426  395  1743

# %%
df=df.loc[df.index!="과목총점"]

# %%
df
# Out:
#        국어  영어  수학  사회   총점
# sXRfu  85  24  28  74  211
# iEqdF  15  12  37  65  129
# lpFzN  64  66  34  16  180
# gYgFi  34  43  15  13  105
# uIhMh  14  11  28  20   73
# CZAOd  87  80  89  44  300
# fjNKW  22  33  19  32  106
# sPGVd  57  89  69   8  223
# XGVUv  90  10  41  29  170
# DHxIc  55  31  66  94  246

# %%
df.sort_values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-4fa95ab19bbe> in <module>
# ----> 1 df.sort_values(df.iloc[:,[0,3]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError:        국어  사회
# sXRfu  85  74
# iEqdF  15  65
# lpFzN  64  16
# ...
